# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
totals_df = pd.read_csv('Data/spreadspoke_scores.csv')

# %% [markdown]
# Dataset preview

# %%
totals_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13499      1/8/2023             2022            18             False
# 13500      1/8/2023             2022            18             False
# 13501      1/8/2023             2022            18             False
# 13502      1/8/2023             2022            18             False
# 13503      1/8/2023             2022            18             False
#
#                    team_home  score_home  score_away          team_away  \
# ...

# %% [markdown]
# Get types of each column

# %%
#totals_df.dtypes

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Prior to 1979 many N/A values for totals, 2022 also has some games that don't have totals listed as they haven't been played yet. Removes years before 1979 and the 2022 season.

# %%
totals_df[(totals_df['schedule_season'] >= 1979) & (totals_df['schedule_season'] <= 2021)]['over_under_line'].isna().sum()
# Out:
# 0

# %%
totals_df = totals_df[(totals_df['schedule_season'] >= 1979) & (totals_df['schedule_season'] <= 2021)]

# %% [markdown]
# Fill N/A of weather_temperature and weather_wind_mph with mean of columns. weather_temperature had 798 N/A out of 10731. weather_wind_mph had 815 N/A out of 10731. Ignore warning.

# %%
weather_temperature_mean = totals_df['weather_temperature'].mean()
weather_wind_mph_mean = totals_df['weather_wind_mph'].mean()
totals_df['weather_temperature'] = totals_df['weather_temperature'].fillna(weather_temperature_mean)
totals_df['weather_wind_mph'] = totals_df['weather_wind_mph'].fillna(weather_wind_mph_mean)
# Out:
# <ipython-input-38-b9aa9aade492>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totals_df['weather_temperature'] = totals_df['weather_temperature'].fillna(weather_temperature_mean)
# <ipython-input-38-b9aa9aade492>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totals_df['weather_wind_mph'] = totals_df['weather_wind_mph'].fillna(weather_wind_mph_mean)

# %%
totals_df.count()
# Out:
# schedule_date          10731
# schedule_season        10731
# schedule_week          10731
# schedule_playoff       10731
# team_home              10731
# score_home             10731
# score_away             10731
# team_away              10731
# team_favorite_id       10731
# spread_favorite        10731
# over_under_line        10731
# stadium                10731
# stadium_neutral        10731
# weather_temperature    10731
# weather_wind_mph       10731
# weather_humidity        6331
# weather_detail          2675
# dtype: int64

# %% [markdown]
# Different possible dataset to use

# %%
games = pd.read_csv("http://www.habitatring.com/games.csv")
