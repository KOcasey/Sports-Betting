# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
totals_df = pd.read_csv('Data/spreadspoke_scores.csv')

# %%
totals_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13499      1/8/2023             2022            18             False
# 13500      1/8/2023             2022            18             False
# 13501      1/8/2023             2022            18             False
# 13502      1/8/2023             2022            18             False
# 13503      1/8/2023             2022            18             False
#
#                    team_home  score_home  score_away          team_away  \
# ...
